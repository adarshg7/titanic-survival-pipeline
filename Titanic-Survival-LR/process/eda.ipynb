# %%
import pandas as pd

# %%
df_gender = pd.read_csv("../DataSet/raw data/train.csv")

# %%
df_g = pd.read_csv("../DataSet/raw data/train.csv")

# %%
df_gender.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df_gender.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
df_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
df = pd.read_csv(r"C:\Users\gopal gupta\Desktop\Titanic ML\DataSet\train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
## Nmae, pclasspassender is not necesaary,

# %%
pd.crosstab(df['Sex'],df['Survived'], normalize='index')
##74% female survived and 18% men surived
# Out:
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
pd.crosstab(df['Pclass'],df['Survived'], normalize='index')
##class 1 has higher survival rate
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=df, x='Age', hue='Survived',multiple='stack',bins=30)
##children have survived more
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data = df, x='Survived', y= 'Age')
##gender and class matter more than age for age above 20 and below 40
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
df.pivot_table(index='Sex', columns='Pclass', values='Survived', aggfunc='mean')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
pd.crosstab(df['Embarked'], df['Survived'], normalize='index')
##embarked with c survuved more
# Out:
# Survived         0         1
# Embarked
# C         0.446429  0.553571
# Q         0.610390  0.389610
# S         0.663043  0.336957

# %%
sns.countplot(data=df, x='Embarked', hue='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df.pivot_table(index='Parch', values='Survived', aggfunc='mean')
## smaller families survived more
# Out:
#        Survived
# Parch
# 0      0.343658
# 1      0.550847
# 2      0.500000
# 3      0.600000
# 4      0.000000
# 5      0.200000
# 6      0.000000

# %%
sns.countplot(data=df, x='Parch',hue='Survived')
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
# This creates a separate chart for each Passenger Class
sns.catplot(data=df, x='Sex', y='Survived', col='Pclass', kind='bar')

# %%
pd.crosstab(df['Fare'],df['Survived'], normalize='index')
# Out:
# Survived         0         1
# Fare
# 0.0000    0.933333  0.066667
# 4.0125    1.000000  0.000000
# 5.0000    1.000000  0.000000
# 6.2375    1.000000  0.000000
# 6.4375    1.000000  0.000000
# ...            ...       ...
# 227.5250  0.250000  0.750000
# 247.5208  0.500000  0.500000
# 262.3750  0.000000  1.000000
# 263.0000  0.500000  0.500000
# 512.3292  0.000000  1.000000
#
# [248 rows x 2 columns]

# %%
sns.countplot(data=df, x='Embarked', hue='Survived')
plt.title('Survival by Port of Embarkation')
plt.show()

# %%
corr_matrix = df.select_dtypes(include=['number']).corr()

# 2. Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap of Titanic Features')
plt.show()

# %%
sns.barplot(data=df, x='Embarked', y='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
sns.lineplot(data=df, x='Parch', y='Survived', marker='o')
# Out:
# <Axes: xlabel='Parch', ylabel='Survived'>
